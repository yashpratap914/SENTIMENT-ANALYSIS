# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !pip install beautifulsoup4
# !pip install textblob
# !pip install mlxtend
# !pip install git+https://github.com/laxmimerit/preprocess_kgptalkie.git --upgrade --force-reinstall
# Out:
# Requirement already satisfied: spacy in c:\users\kiit\anaconda3\lib\site-packages (3.6.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (8.1.12)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: setuptools in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (63.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: packaging>=20.0 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (0.10.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: jinja2 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\kiit\anaconda3\lib\site-packages (from spacy) (1.10.7)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\kiit\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\kiit\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\kiit\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kiit\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kiit\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiit\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\kiit\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\kiit\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: colorama in c:\users\kiit\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\kiit\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\kiit\anaconda3\lib\site-packages (from jinja2->spacy) (2.0.1)
# Collecting en-core-web-sm==3.6.0
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001FA92FCD940>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001FA92FCDC70>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001FA92FCDE20>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl
#   WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001FA92FCDFD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl
#   WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001FA92FF31C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl
# ERROR: Could not install packages due to an OSError: HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: /explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (Caused by NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001FA92FF3370>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Requirement already satisfied: beautifulsoup4 in c:\users\kiit\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kiit\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.1)
# Requirement already satisfied: textblob in c:\users\kiit\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\kiit\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: click in c:\users\kiit\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\kiit\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: tqdm in c:\users\kiit\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kiit\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: colorama in c:\users\kiit\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# Requirement already satisfied: mlxtend in c:\users\kiit\anaconda3\lib\site-packages (0.23.0)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\kiit\anaconda3\lib\site-packages (from mlxtend) (1.9.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\kiit\anaconda3\lib\site-packages (from mlxtend) (1.24.3)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\kiit\anaconda3\lib\site-packages (from mlxtend) (3.5.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\kiit\anaconda3\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\kiit\anaconda3\lib\site-packages (from mlxtend) (1.4.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\kiit\anaconda3\lib\site-packages (from mlxtend) (1.0.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kiit\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kiit\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\kiit\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Collecting git+https://github.com/laxmimerit/preprocess_kgptalkie.git
#   Cloning https://github.com/laxmimerit/preprocess_kgptalkie.git to c:\users\kiit\appdata\local\temp\pip-req-build-z_ncjzat
#   Resolved https://github.com/laxmimerit/preprocess_kgptalkie.git to commit 96bf02872d9756f29d6cddb8aafaedcd2a39bbb4
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: preprocess-kgptalkie
#   Building wheel for preprocess-kgptalkie (setup.py): started
#   Building wheel for preprocess-kgptalkie (setup.py): finished with status 'done'
#   Created wheel for preprocess-kgptalkie: filename=preprocess_kgptalkie-0.1.3-py3-none-any.whl size=7647 sha256=1be8d1ff57b0d2b7bd15409e010fb3d345fe917f97fe67a55084d45ccf24667c
#   Stored in directory: C:\Users\KIIT\AppData\Local\Temp\pip-ephem-wheel-cache-1dmlnis4\wheels\d1\c3\bb\559fe93e652b51cbc532f17e9693f3b70055f8560cf06c1fb3
# Successfully built preprocess-kgptalkie
# Installing collected packages: preprocess-kgptalkie
#   Attempting uninstall: preprocess-kgptalkie
#     Found existing installation: preprocess-kgptalkie 0.1.3
#     Uninstalling preprocess-kgptalkie-0.1.3:
#       Successfully uninstalled preprocess-kgptalkie-0.1.3
# Successfully installed preprocess-kgptalkie-0.1.3
#   Running command git clone --filter=blob:none --quiet https://github.com/laxmimerit/preprocess_kgptalkie.git 'C:\Users\KIIT\AppData\Local\Temp\pip-req-build-z_ncjzat'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import preprocess_kgptalkie as ps

# %%
df = pd.read_csv('https://github.com/laxmimerit/All-CSV-ML-Data-Files-Download/raw/master/IMDB-Dataset.csv')

# %%
df.shape
# Out:
# (50000, 2)

# %%
df.columns
# Out:
# Index(['review', 'sentiment'], dtype='object')

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# PREPROCESSING

# %%
df['word_counts'] = df['review'].apply(lambda x: ps.get_wordcounts(x))
df['char_counts'] = df['review'].apply(lambda x: ps.get_charcounts(x))
df['avg_wordlength'] = df['review'].apply(lambda x: ps.get_avg_wordlength(x))
df['stopwords_counts'] = df['review'].apply(lambda x: ps.get_stopwords_counts(x))

df['review'] = df['review'].apply(lambda x: ps.remove_html_tags(x))
df['review'] = df['review'].str.lower()
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
df['review_without_stopwords'] = df['review'].apply(lambda x: ps.remove_stopwords(x))

# %%
df.head()
# Out:
#                                               review sentiment  word_counts  \
# 0  one of the other reviewers has mentioned that ...  positive          307
# 1  a wonderful little production. the filming tec...  positive          162
# 2  i thought this was a wonderful way to spend ti...  positive          166
# 3  basically there's a family where a little boy ...  negative          138
# 4  petter mattei's "love in the time of money" is...  positive          230
#
#    char_counts  avg_wordlength  stopwords_counts  \
# 0         1455        4.739414               135
# 1          837        5.166667                71
# 2          761        4.584337                81
# 3          611        4.427536                63
# 4         1088        4.730435               107
#
#                             review_without_stopwords
# 0  reviewers mentioned watching 1 oz episode you'...
# 1  wonderful little production. filming technique...
# 2  thought wonderful way spend time hot summer we...
# 3  basically there's family little boy (jake) thi...
# 4  petter mattei's "love time money" visually stu...

# %% [markdown]
# STOP WORDS

# %%
df.columns
# Out:
# Index(['review', 'sentiment', 'word_counts', 'char_counts', 'avg_wordlength',
#        'stopwords_counts', 'review_without_stopwords'],
#       dtype='object')

# %%
import seaborn as sns

# %%
plt.figure(figsize=(16,8))

plt.subplot(2,2,1)
# sns.barplot(x='sentiment', y='word_counts', data=df)
sns.histplot(data=df, x='word_counts', hue='sentiment', kde=True)
plt.title('Word counts')

plt.subplot(2,2,2)
sns.histplot(data=df, x='char_counts', hue='sentiment', kde=True)
plt.title('Char counts')

plt.subplot(2,2,3)
sns.histplot(data=df, x='avg_wordlength', hue='sentiment', kde=True)
plt.title('Avg Word Length')

plt.subplot(2,2,4)
sns.histplot(data=df, x='stopwords_counts', hue='sentiment', kde=True)
plt.title('Stopwords counts')

plt.tight_layout()
plt.show()

# %%
# steps
# train test split -> tfidf -> ml algo -> fit -> prediction -> evaluation

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(df['review'], 
                                                    df['sentiment'],
                                                    test_size=0.2,
                                                    random_state=0,
                                                    stratify=df['sentiment']
                                                   )

# %%
X_train.shape, X_test.shape
# Out:
# ((40000,), (10000,))

# %%
clf = Pipeline([('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
y_pred = clf.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.89      0.90      5000
#     positive       0.89      0.91      0.90      5000
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000

# %%
from mlxtend.plotting import plot_confusion_matrix

cm = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(cm, class_names=clf.classes_)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:xlabel='predicted label', ylabel='true label'>)

# %%
clf.predict(['Wow, this is amazing lesson'])
# Out:
# array(['positive'], dtype=object)

# %%
clf.predict(['Wow, this sucks'])
# Out:
# array(['negative'], dtype=object)

# %%
clf.predict(['please like this video. it helps me a lot'])
# Out:
# array(['positive'], dtype=object)

# %%
import pickle

pickle.dump(clf, open('sentiment_analysis.pkl', 'wb'))
